# %%
# Test schedule fetch
from datetime import datetime
from sportradar_config import fetch_sportradar_nba
# Out:
# [SPORTRADAR CONFIG] After loading .env:
# [SPORTRADAR CONFIG] SPORTRADAR_NBA_API_KEY: Set (QIw7oxBqSD...)
# [SPORTRADAR CONFIG] SPORTRADAR_SYNERGY_API_KEY: Set (QIw7oxBqSD...)
# [SPORTRADAR CONFIG] SPORTRADAR_GLOBAL_API_KEY: Set (QIw7oxBqSD...)
# [SPORTRADAR CONFIG] ✓ NBA API configured!
# [SPORTRADAR CONFIG] ✓ Synergy API configured!
# [SPORTRADAR CONFIG] ✓ Global Basketball API configured!

# %%
# Test with the date from your example
endpoint = "games/2026/01/09/schedule.json"
response = fetch_sportradar_nba(endpoint, use_headers=True)
print(f"Found {len(response.get('games', []))} games")
response.get('games', [])
# Out:
# [SPORTRADAR] Fetching URL: https://api.sportradar.com/nba/trial/v8/en/games/2026/01/09/schedule.json...
# Found 10 games
# [{'id': 'df603a98-aa2f-4613-82c5-44b4dfd47cde',
#   'status': 'inprogress',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T00:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62925421',
#   'reference': '0022500533',
#   'time_zones': {'venue': 'US/Eastern',
#    'home': 'US/Eastern',
#    'away': 'US/Eastern'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': 'aecd8da6-0404-599c-a792-4b33fb084a2a',
#    'name': 'Kia Center',
#    'capacity': 18846,
#    'address': '400 W. Church Street',
#    'city': 'Orlando',
#    'state': 'FL',
#    'zip': '32801',
#    'country': 'USA',
#    'sr_id': 'sr:venue:6936',
#    'location': {'lat': '28.539167', 'lng': '-81.383611'}},
#   'broadcasts': [{'network': 'FDSFL',
#     'type': 'TV',
#     'locale': 'Home',
#     'channel': '654'},
#    {'network': 'NBCS-PH', 'type': 'TV', 'locale': 'Away'}],
#   'home': {'name': 'Orlando Magic',
#    'alias': 'ORL',
#    'id': '583ed157-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3437',
#    'reference': '1610612753'},
#   'away': {'name': 'Philadelphia 76ers',
#    'alias': 'PHI',
#    'id': '583ec87d-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3420',
#    'reference': '1610612755'}},
#  {'id': '175641d8-59b7-48a0-b623-274f38ecde69',
#   'status': 'inprogress',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T00:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62926257',
#   'reference': '0022500532',
#   'time_zones': {'venue': 'US/Eastern',
#    'home': 'US/Eastern',
#    'away': 'US/Eastern'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '7d69b080-91ca-53c9-9302-45c1a72c5549',
#    'name': 'TD Garden',
#    'capacity': 18624,
#    'address': '100 Legends Way',
#    'city': 'Boston',
#    'state': 'MA',
#    'zip': '02114',
#    'country': 'USA',
#    'sr_id': 'sr:venue:5940',
#    'location': {'lat': '42.366303', 'lng': '-71.062228'}},
#   'broadcasts': [{'network': 'NBCS-BOS',
#     'type': 'TV',
#     'locale': 'Home',
#     'channel': '630'},
#    {'network': 'SportsNet', 'type': 'TV', 'locale': 'Away'}],
#   'home': {'name': 'Boston Celtics',
#    'alias': 'BOS',
#    'id': '583eccfa-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3422',
#    'reference': '1610612738'},
#   'away': {'name': 'Toronto Raptors',
#    'alias': 'TOR',
#    'id': '583ecda6-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3433',
#    'reference': '1610612761'}},
#  {'id': '19c761f8-b317-489f-901a-b1864c2faa3f',
#   'status': 'inprogress',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T00:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62924335',
#   'reference': '0022500534',
#   'time_zones': {'venue': 'US/Eastern',
#    'home': 'US/Eastern',
#    'away': 'US/Central'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': 'f62d5b49-d646-56e9-ba60-a875a00830f8',
#    'name': 'Capital One Arena',
#    'capacity': 20356,
#    'address': '601 F Street NW',
#    'city': 'Washington',
#    'state': 'DC',
#    'zip': '20004',
#    'country': 'USA',
#    'sr_id': 'sr:venue:6016',
#    'location': {'lat': '38.898056', 'lng': '-77.020833'}},
#   'broadcasts': [{'network': 'Gulf Coast Sports',
#     'type': 'TV',
#     'locale': 'Away'},
#    {'network': 'Pelicans+', 'type': 'Internet', 'locale': 'Away'},
#    {'network': 'MNMT', 'type': 'TV', 'locale': 'Home', 'channel': '642'},
#    {'network': 'WVUE', 'type': 'TV', 'locale': 'Away'}],
#   'home': {'name': 'Washington Wizards',
#    'alias': 'WAS',
#    'id': '583ec8d4-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3431',
#    'reference': '1610612764'},
#   'away': {'name': 'New Orleans Pelicans',
#    'alias': 'NOP',
#    'id': '583ecc9a-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:5539',
#    'reference': '1610612740'}},
#  {'id': '46fb3da9-5b19-4bc4-aad5-0e9ad56f54a8',
#   'status': 'inprogress',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T00:30:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62925457',
#   'reference': '0022500535',
#   'time_zones': {'venue': 'US/Eastern',
#    'home': 'US/Eastern',
#    'away': 'US/Pacific'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '7a330bcd-ac0f-50ca-bc29-2460e5c476b3',
#    'name': 'Barclays Center',
#    'capacity': 17732,
#    'address': '620 Atlantic Avenue',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'zip': '11217',
#    'country': 'USA',
#    'sr_id': 'sr:venue:36132',
#    'location': {'lat': '40.682957', 'lng': '-73.975165'}},
#   'broadcasts': [{'network': 'YES',
#     'type': 'TV',
#     'locale': 'Home',
#     'channel': '631'},
#    {'network': 'FDSSC', 'type': 'TV', 'locale': 'Away', 'channel': '693'}],
#   'home': {'name': 'Brooklyn Nets',
#    'alias': 'BKN',
#    'id': '583ec9d6-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3436',
#    'reference': '1610612751'},
#   'away': {'name': 'LA Clippers',
#    'alias': 'LAC',
#    'id': '583ecdfb-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3425',
#    'reference': '1610612746'}},
#  {'id': '541c979c-e73a-4bf1-8647-54cfde416ccb',
#   'status': 'scheduled',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T01:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62925527',
#   'reference': '0022500536',
#   'time_zones': {'venue': 'US/Central',
#    'home': 'US/Central',
#    'away': 'US/Central'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '7657c204-a20b-527a-99cb-dc29218462aa',
#    'name': 'FedExForum',
#    'capacity': 18119,
#    'address': '191 Beale Street',
#    'city': 'Memphis',
#    'state': 'TN',
#    'zip': '38103',
#    'country': 'USA',
#    'sr_id': 'sr:venue:6926',
#    'location': {'lat': '35.138142', 'lng': '-90.050427'}},
#   'broadcasts': [{'network': 'FDSSE',
#     'type': 'TV',
#     'locale': 'Home',
#     'channel': '649'},
#    {'network': 'FDSOK', 'type': 'TV', 'locale': 'Away', 'channel': '675'},
#    {'network': 'NBA TV', 'type': 'TV', 'locale': 'National', 'channel': '216'},
#    {'network': 'WMC-TV', 'type': 'TV', 'locale': 'Home'}],
#   'home': {'name': 'Memphis Grizzlies',
#    'alias': 'MEM',
#    'id': '583eca88-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3415',
#    'reference': '1610612763'},
#   'away': {'name': 'Oklahoma City Thunder',
#    'alias': 'OKC',
#    'id': '583ecfff-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3418',
#    'reference': '1610612760'}},
#  {'id': 'af3e1456-aa31-4f4a-a72b-758316540026',
#   'status': 'scheduled',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T02:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62925291',
#   'reference': '0022500538',
#   'time_zones': {'venue': 'US/Arizona',
#    'home': 'US/Arizona',
#    'away': 'US/Eastern'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '1d2e59b2-2479-5f84-a6a7-e82f65dd8442',
#    'name': 'Mortgage Matchup Center',
#    'capacity': 18422,
#    'address': '201 E. Jefferson Street',
#    'city': 'Phoenix',
#    'state': 'AZ',
#    'zip': '85004',
#    'country': 'USA',
#    'sr_id': 'sr:venue:6938',
#    'location': {'lat': '33.445833', 'lng': '-112.071389'}},
#   'broadcasts': [{'network': 'MSG',
#     'type': 'TV',
#     'locale': 'Away',
#     'channel': '634'},
#    {'network': 'AZFamily', 'type': 'TV', 'locale': 'Home'},
#    {'network': 'Suns+', 'type': 'Internet', 'locale': 'Home'}],
#   'home': {'name': 'Phoenix Suns',
#    'alias': 'PHX',
#    'id': '583ecfa8-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3416',
#    'reference': '1610612756'},
#   'away': {'name': 'New York Knicks',
#    'alias': 'NYK',
#    'id': '583ec70e-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3421',
#    'reference': '1610612752'}},
#  {'id': '15f9519e-83d3-4df6-8cc5-a6c2e437fdbd',
#   'status': 'scheduled',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T02:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62925135',
#   'reference': '0022500537',
#   'time_zones': {'venue': 'US/Mountain',
#    'home': 'US/Mountain',
#    'away': 'US/Eastern'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '1a28ef88-76c9-5bcc-b4ee-51d30ca98f4f',
#    'name': 'Ball Arena',
#    'capacity': 19520,
#    'address': '1000 Chopper Circle',
#    'city': 'Denver',
#    'state': 'CO',
#    'zip': '80204',
#    'country': 'USA',
#    'sr_id': 'sr:venue:5976',
#    'location': {'lat': '39.749034', 'lng': '-105.007604'}},
#   'broadcasts': [{'network': 'FDSSE',
#     'type': 'TV',
#     'locale': 'Away',
#     'channel': '649'},
#    {'network': 'ALT', 'type': 'TV', 'locale': 'Home', 'channel': '681'},
#    {'network': 'WANF', 'type': 'TV', 'locale': 'Away'},
#    {'network': 'Peachtree Sports Network', 'type': 'TV', 'locale': 'Away'}],
#   'home': {'name': 'Denver Nuggets',
#    'alias': 'DEN',
#    'id': '583ed102-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3417',
#    'reference': '1610612743'},
#   'away': {'name': 'Atlanta Hawks',
#    'alias': 'ATL',
#    'id': '583ecb8f-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3423',
#    'reference': '1610612737'}},
#  {'id': '464a880d-aa4c-4f1a-aa8b-73bc22b9eef5',
#   'status': 'scheduled',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T03:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62924341',
#   'reference': '0022500539',
#   'time_zones': {'venue': 'US/Pacific',
#    'home': 'US/Pacific',
#    'away': 'US/Pacific'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '938016dc-9e1d-4abc-88f5-3a7d772332e6',
#    'name': 'Chase Center',
#    'capacity': 18064,
#    'address': '1 Warriors Way',
#    'city': 'San Francisco',
#    'state': 'CA',
#    'zip': '94158',
#    'country': 'USA',
#    'sr_id': 'sr:venue:44446',
#    'location': {'lat': '37.7679', 'lng': '-122.3873'}},
#   'broadcasts': [{'network': 'NBCS-BA',
#     'type': 'TV',
#     'locale': 'Home',
#     'channel': '696'},
#    {'network': 'NBCS-CA', 'type': 'TV', 'locale': 'Away', 'channel': '698'}],
#   'home': {'name': 'Golden State Warriors',
#    'alias': 'GSW',
#    'id': '583ec825-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3428',
#    'reference': '1610612744'},
#   'away': {'name': 'Sacramento Kings',
#    'alias': 'SAC',
#    'id': '583ed0ac-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3413',
#    'reference': '1610612758'}},
#  {'id': 'e33753e6-3d09-489b-82e7-cc4a3826f074',
#   'status': 'scheduled',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T03:00:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62926355',
#   'reference': '0022500540',
#   'time_zones': {'venue': 'US/Pacific',
#    'home': 'US/Pacific',
#    'away': 'US/Central'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '1d1f74a2-7b35-56f0-8cbd-552c51cb2c14',
#    'name': 'Moda Center',
#    'capacity': 19393,
#    'address': '1 Center Court',
#    'city': 'Portland',
#    'state': 'OR',
#    'zip': '97227',
#    'country': 'USA',
#    'sr_id': 'sr:venue:6940',
#    'location': {'lat': '45.531667', 'lng': '-122.666667'}},
#   'broadcasts': [{'network': 'KUNP', 'type': 'TV', 'locale': 'Home'},
#    {'network': 'SCHN', 'type': 'TV', 'locale': 'Away', 'channel': '674'}],
#   'home': {'name': 'Portland Trail Blazers',
#    'alias': 'POR',
#    'id': '583ed056-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3414',
#    'reference': '1610612757'},
#   'away': {'name': 'Houston Rockets',
#    'alias': 'HOU',
#    'id': '583ecb3a-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3412',
#    'reference': '1610612745'}},
#  {'id': '38a66f9a-f333-436f-807b-d15fe54de874',
#   'status': 'scheduled',
#   'coverage': 'full',
#   'scheduled': '2026-01-10T03:30:00+00:00',
#   'track_on_court': True,
#   'sr_id': 'sr:match:62924717',
#   'reference': '0022500541',
#   'time_zones': {'venue': 'US/Pacific',
#    'home': 'US/Pacific',
#    'away': 'US/Central'},
#   'season': {'id': 'a7c6c8ee-c5ba-4a1a-abf5-723e1539f81b',
#    'year': 2025,
#    'type': 'REG'},
#   'venue': {'id': '792ec100-691e-5e16-8ef8-79b2b6ee38ba',
#    'name': 'Crypto.com Arena',
#    'capacity': 18997,
#    'address': '1111 S. Figueroa Street',
#    'city': 'Los Angeles',
#    'state': 'CA',
#    'zip': '90015',
#    'country': 'USA',
#    'sr_id': 'sr:venue:6008',
#    'location': {'lat': '34.043059', 'lng': '-118.267223'}},
#   'broadcasts': [{'network': 'SportsNet LA',
#     'type': 'TV',
#     'locale': 'Home',
#     'channel': '690'},
#    {'network': 'FDSWI', 'type': 'TV', 'locale': 'Away', 'channel': '669'},
#    {'network': 'NBA TV',
#     'type': 'TV',
#     'locale': 'National',
#     'channel': '216'}],
#   'home': {'name': 'Los Angeles Lakers',
#    'alias': 'LAL',
#    'id': '583ecae2-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3427',
#    'reference': '1610612747'},
#   'away': {'name': 'Milwaukee Bucks',
#    'alias': 'MIL',
#    'id': '583ecefd-fb46-11e1-82cb-f4ce4684ea4c',
#    'sr_id': 'sr:team:3410',
#    'reference': '1610612749'}}]

# %%
# Test box score (replace GAME_ID with actual game ID from schedule)
game_id = "df603a98-aa2f-4613-82c5-44b4dfd47cde"
endpoint = f"games/{game_id}/boxscore.json"
print(f"Fetching box score for game: {game_id}")
print(f"Endpoint: {endpoint}")

try:
    boxscore = fetch_sportradar_nba(endpoint, use_headers=True)
    print(f"\n✓ Box score retrieved successfully!")
    print(f"Response type: {type(boxscore)}")
    print(f"Response keys: {list(boxscore.keys()) if isinstance(boxscore, dict) else 'Not a dict'}")
    
    if isinstance(boxscore, dict):
        # Boxscore response has game data at root level
        game_id_response = boxscore.get('id', 'N/A')
        game_status = boxscore.get('status', 'N/A')
        print(f"\nGame Info:")
        print(f"  Game ID: {game_id_response}")
        print(f"  Status: {game_status}")
        print(f"  Scheduled: {boxscore.get('scheduled', 'N/A')}")
        
        if 'home' in boxscore:
            home = boxscore['home']
            print(f"\n  Home Team: {home.get('name', 'N/A')} ({home.get('alias', 'N/A')})")
            print(f"    Points: {home.get('points', 'N/A')}")
            if 'leaders' in home:
                print(f"    Leaders available: {list(home['leaders'].keys())}")
        
        if 'away' in boxscore:
            away = boxscore['away']
            print(f"\n  Away Team: {away.get('name', 'N/A')} ({away.get('alias', 'N/A')})")
            print(f"    Points: {away.get('points', 'N/A')}")
            if 'leaders' in away:
                print(f"    Leaders available: {list(away['leaders'].keys())}")
        
        # Test extraction functions
        print(f"\n--- Testing Extraction Functions ---")
        import sys
        import os
        from pathlib import Path
        
        # Find project root by looking for 'scripts' directory
        current = Path.cwd()
        project_root = None
        
        # Try going up directories until we find 'scripts' folder
        for parent in [current] + list(current.parents):
            if (parent / 'scripts' / 'sportradar_fetch_game_logs.py').exists():
                project_root = parent
                break
        
        if project_root is None:
            # Fallback: use known workspace path
            project_root = Path('/Users/jackborman/Desktop/PycharmProjects/NBA')
        
        if str(project_root) not in sys.path:
            sys.path.insert(0, str(project_root))
        
        print(f"Project root: {project_root}")
        
        from scripts.sportradar_fetch_game_logs import extract_player_game_logs_from_boxscore, extract_team_game_logs_from_boxscore
        
        player_logs = extract_player_game_logs_from_boxscore(boxscore)
        print(f"Extracted {len(player_logs)} player logs")
        if len(player_logs) > 0:
            print(f"  Sample player: {player_logs[0].get('PLAYER_NAME', 'N/A')} - {player_logs[0].get('points', 'N/A')} points")
        
        team_logs = extract_team_game_logs_from_boxscore(boxscore)
        print(f"Extracted {len(team_logs)} team logs")
        if len(team_logs) > 0:
            print(f"  Sample team: {team_logs[0].get('TEAM_ABBREVIATION', 'N/A')} - {team_logs[0].get('POINTS', 'N/A')} points")
        
except Exception as e:
    print(f"\n✗ Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Fetching box score for game: df603a98-aa2f-4613-82c5-44b4dfd47cde
# Endpoint: games/df603a98-aa2f-4613-82c5-44b4dfd47cde/boxscore.json
# [SPORTRADAR] Fetching URL: https://api.sportradar.com/nba/trial/v8/en/games/df603a98-aa2f-4613-82c5-44b4dfd47cde/boxscore.json...
#
# ✓ Box score retrieved successfully!
# Response type: <class 'dict'>
# Response keys: ['id', 'status', 'coverage', 'scheduled', 'lead_changes', 'times_tied', 'clock', 'quarter', 'track_on_court', 'reference', 'entry_mode', 'sr_id', 'clock_decimal', 'broadcasts', 'time_zones', 'season', 'home', 'away']
#
# Game Info:
#   Game ID: df603a98-aa2f-4613-82c5-44b4dfd47cde
#   Status: halftime
#   Scheduled: 2026-01-10T00:00:00+00:00
#
#   Home Team: Magic (ORL)
#     Points: 54
#     Leaders available: ['points', 'rebounds', 'assists']
#
#   Away Team: 76ers (PHI)
#     Points: 53
#     Leaders available: ['points', 'rebounds', 'assists']
#
# --- Testing Extraction Functions ---
# Project root: /Users/jackborman/Desktop/PycharmProjects/NBA
# [SUPABASE CONFIG] Loading .env from: /Users/jackborman/Desktop/PycharmProjects/NBA/.env
# [SUPABASE CONFIG] .env exists: True
# [SUPABASE CONFIG] After loading .env:
# [SUPABASE CONFIG] SUPABASE_URL: Set (https://qhrgekcowkgwcaaqyqvv.s...)
# [SUPABASE CONFIG] SUPABASE_KEY: Set (sb_publishable_-wJMp...)
# [SUPABASE CONFIG] SUPABASE_KEY length: 46
# [SUPABASE CONFIG] ✓ Supabase configured successfully!
# Extracted 6 player logs
#   Sample player: Anthony Black - 14 points
# Extracted 2 team logs
#   Sample team: ORL - 54 points
