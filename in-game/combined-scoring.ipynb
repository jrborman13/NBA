# %%
import nba_api.stats.endpoints
import requests
import json
import pandas as pd
import nba_api

# %%
import nba_api.stats.endpoints
from nba_api.library.http import NBAHTTP
import time

NBAHTTP.headers = {
    "Host": "stats.nba.com",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Referer": "https://www.nba.com/",
    "Origin": "https://www.nba.com",
    "Connection": "keep-alive",
}

time.sleep(1)

wolves_player_logs = nba_api.stats.endpoints.PlayerGameLogs(
    season_nullable='2025-26',
    team_id_nullable='1610612750'
).get_data_frames()[0]

wolves_player_logs
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[8], line 18
#       5 NBAHTTP.headers = {
#       6     "Host": "stats.nba.com",
#       7     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
#    (...)     13     "Connection": "keep-alive",
#      14 }
#      16 time.sleep(1)
# ---> 18 wolves_player_logs = nba_api.stats.endpoints.PlayerGameLogs(
#      19     season_nullable='2025-26',
#      20     team_id_nullable='1610612750'
#      21 ).get_data_frames()[0]
#      23 wolves_player_logs
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/nba_api/stats/endpoints/playergamelogs.py:154, in PlayerGameLogs.__init__(self, date_from_nullable, date_to_nullable, game_segment_nullable, last_n_games_nullable, league_id_nullable, location_nullable, measure_type_player_game_logs_nullable, month_nullable, opp_team_id_nullable, outcome_nullable, po_round_nullable, per_mode_simple_nullable, period_nullable, player_id_nullable, season_nullable, season_segment_nullable, season_type_nullable, shot_clock_range_nullable, team_id_nullable, vs_conference_nullable, vs_division_nullable, proxy, headers, timeout, get_request)
#     130 self.parameters = {
#     131     "DateFrom": date_from_nullable,
#     132     "DateTo": date_to_nullable,
#    (...)    151     "VsDivision": vs_division_nullable,
#     152 }
#     153 if get_request:
# --> 154     self.get_request()
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/nba_api/stats/endpoints/playergamelogs.py:157, in PlayerGameLogs.get_request(self)
#     156 def get_request(self):
# --> 157     self.nba_response = NBAStatsHTTP().send_api_request(
#     158         endpoint=self.endpoint,
#     159         parameters=self.parameters,
#     160         proxy=self.proxy,
#     161         headers=self.headers,
#     162         timeout=self.timeout,
#     163     )
#     164     self.load_response()
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/nba_api/library/http.py:160, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     157         print("loading from file...")
#     159 if not contents:
# --> 160     response = self.get_session().get(
#     161         url=base_url,
#     162         params=parameters,
#     163         headers=request_headers,
#     164         proxies=proxies,
#     165         timeout=timeout,
#     166     )
#     167     url = response.url
#     168     status_code = response.status_code
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/adapters.py:690, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     688     raise SSLError(e, request=request)
#     689 elif isinstance(e, ReadTimeoutError):
# --> 690     raise ReadTimeout(e, request=request)
#     691 elif isinstance(e, _InvalidHeader):
#     692     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
pip show nba_api
# Out:
# Name: nba_api
# Version: 1.10.2
# Summary: An API Client package to access the APIs for NBA.com
# Home-page:
# Author: Swar Patel
# Author-email: <swar.m.patel@gmail.com>
# License: MIT
# Location: /Users/jackborman/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages
# Requires: numpy, pandas, requests
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
wolves_player_logs = nba_api.stats.endpoints.PlayerGameLogs(season_nullable='2025-26',team_id_nullable='1610612750').get_data_frames()[0]

wolves_player_logs
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wolves_player_logs = nba_api.stats.endpoints.PlayerGameLogs(season_nullable='2025-26',team_id_nullable='1610612750').get_data_frames()[0]
#       3 wolves_player_logs
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/nba_api/stats/endpoints/playergamelogs.py:154, in PlayerGameLogs.__init__(self, date_from_nullable, date_to_nullable, game_segment_nullable, last_n_games_nullable, league_id_nullable, location_nullable, measure_type_player_game_logs_nullable, month_nullable, opp_team_id_nullable, outcome_nullable, po_round_nullable, per_mode_simple_nullable, period_nullable, player_id_nullable, season_nullable, season_segment_nullable, season_type_nullable, shot_clock_range_nullable, team_id_nullable, vs_conference_nullable, vs_division_nullable, proxy, headers, timeout, get_request)
#     130 self.parameters = {
#     131     "DateFrom": date_from_nullable,
#     132     "DateTo": date_to_nullable,
#    (...)    151     "VsDivision": vs_division_nullable,
#     152 }
#     153 if get_request:
# --> 154     self.get_request()
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/nba_api/stats/endpoints/playergamelogs.py:157, in PlayerGameLogs.get_request(self)
#     156 def get_request(self):
# --> 157     self.nba_response = NBAStatsHTTP().send_api_request(
#     158         endpoint=self.endpoint,
#     159         parameters=self.parameters,
#     160         proxy=self.proxy,
#     161         headers=self.headers,
#     162         timeout=self.timeout,
#     163     )
#     164     self.load_response()
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/nba_api/library/http.py:160, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     157         print("loading from file...")
#     159 if not contents:
# --> 160     response = self.get_session().get(
#     161         url=base_url,
#     162         params=parameters,
#     163         headers=request_headers,
#     164         proxies=proxies,
#     165         timeout=timeout,
#     166     )
#     167     url = response.url
#     168     status_code = response.status_code
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/requests/adapters.py:690, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     688     raise SSLError(e, request=request)
#     689 elif isinstance(e, ReadTimeoutError):
# --> 690     raise ReadTimeout(e, request=request)
#     691 elif isinstance(e, _InvalidHeader):
#     692     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
wolves_player_logs[wolves_player_logs['PLAYER_NAME'] == 'Donte DiVincenzo']
# Out:
#     SEASON_YEAR  PLAYER_ID       PLAYER_NAME NICKNAME     TEAM_ID  \
# 7       2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 18      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 26      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 36      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 47      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 57      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 68      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 76      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 88      2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 105     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 112     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 123     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 135     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 144     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 152     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 164     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 177     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 188     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 203     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 213     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 222     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 237     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 248     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 262     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 272     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 280     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 293     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 298     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 307     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 317     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 330     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 339     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 351     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 359     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 368     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 381     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 393     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 402     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 413     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 423     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 431     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 446     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 454     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 468     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 478     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 493     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 501     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 513     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 527     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 540     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 549     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 561     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 571     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 588     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 613     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 636     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 659     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
# 666     2025-26    1628978  Donte DiVincenzo    Donte  1610612750
#
#     TEAM_ABBREVIATION               TEAM_NAME     GAME_ID  \
# 7                 MIN  Minnesota Timberwolves  0022500760
# 18                MIN  Minnesota Timberwolves  0022500744
# 26                MIN  Minnesota Timberwolves  0022500727
# 36                MIN  Minnesota Timberwolves  0022500714
# 47                MIN  Minnesota Timberwolves  0022500700
# 57                MIN  Minnesota Timberwolves  0022500686
# 68                MIN  Minnesota Timberwolves  0022500677
# 76                MIN  Minnesota Timberwolves  0022500663
# 88                MIN  Minnesota Timberwolves  0022500644
# 105               MIN  Minnesota Timberwolves  0022500631
# 112               MIN  Minnesota Timberwolves  0022500616
# 123               MIN  Minnesota Timberwolves  0022500598
# 135               MIN  Minnesota Timberwolves  0022500591
# 144               MIN  Minnesota Timberwolves  0022500566
# 152               MIN  Minnesota Timberwolves  0022500552
# 164               MIN  Minnesota Timberwolves  0022500542
# 177               MIN  Minnesota Timberwolves  0022500530
# 188               MIN  Minnesota Timberwolves  0022500513
# 203               MIN  Minnesota Timberwolves  0022500498
# 213               MIN  Minnesota Timberwolves  0022500486
# 222               MIN  Minnesota Timberwolves  0022500463
# 237               MIN  Minnesota Timberwolves  0022500452
# 248               MIN  Minnesota Timberwolves  0022500439
# 262               MIN  Minnesota Timberwolves  0022500013
# 272               MIN  Minnesota Timberwolves  0022500416
# 280               MIN  Minnesota Timberwolves  0022500400
# 293               MIN  Minnesota Timberwolves  0022500385
# 298               MIN  Minnesota Timberwolves  0022500368
# 307               MIN  Minnesota Timberwolves  0022501220
# 317               MIN  Minnesota Timberwolves  0022501215
# 330               MIN  Minnesota Timberwolves  0022500365
# 339               MIN  Minnesota Timberwolves  0022500355
# 351               MIN  Minnesota Timberwolves  0022500337
# 359               MIN  Minnesota Timberwolves  0022500321
# 368               MIN  Minnesota Timberwolves  0022500306
# 381               MIN  Minnesota Timberwolves  0022500293
# 393               MIN  Minnesota Timberwolves  0022500064
# 402               MIN  Minnesota Timberwolves  0022500292
# 413               MIN  Minnesota Timberwolves  0022500053
# 423               MIN  Minnesota Timberwolves  0022500259
# 431               MIN  Minnesota Timberwolves  0022500246
# 446               MIN  Minnesota Timberwolves  0022500232
# 454               MIN  Minnesota Timberwolves  0022500044
# 468               MIN  Minnesota Timberwolves  0022500205
# 478               MIN  Minnesota Timberwolves  0022500197
# 493               MIN  Minnesota Timberwolves  0022500036
# 501               MIN  Minnesota Timberwolves  0022500175
# 513               MIN  Minnesota Timberwolves  0022500156
# 527               MIN  Minnesota Timberwolves  0022500143
# 540               MIN  Minnesota Timberwolves  0022500136
# 549               MIN  Minnesota Timberwolves  0022500008
# 561               MIN  Minnesota Timberwolves  0022500110
# 571               MIN  Minnesota Timberwolves  0022500019
# 588               MIN  Minnesota Timberwolves  0022500089
# 613               MIN  Minnesota Timberwolves  0012500064
# 636               MIN  Minnesota Timberwolves  0012500039
# 659               MIN  Minnesota Timberwolves  0012500036
# 666               MIN  Minnesota Timberwolves  0012500028
#
#                GAME_DATE      MATCHUP  ... PFD_RANK  PTS_RANK  \
# 7    2026-02-08T00:00:00  MIN vs. LAC  ...      199       579
# 18   2026-02-06T00:00:00  MIN vs. NOP  ...      310       387
# 26   2026-02-04T00:00:00    MIN @ TOR  ...      463       172
# 36   2026-02-02T00:00:00    MIN @ MEM  ...      199        87
# 47   2026-01-31T00:00:00    MIN @ MEM  ...      463       255
# 57   2026-01-29T00:00:00  MIN vs. OKC  ...      310       255
# 68   2026-01-28T00:00:00    MIN @ DAL  ...      463       341
# 76   2026-01-26T00:00:00  MIN vs. GSW  ...      463       172
# 88   2026-01-25T00:00:00  MIN vs. GSW  ...      310        80
# 105  2026-01-22T00:00:00  MIN vs. CHI  ...      127       255
# 112  2026-01-20T00:00:00    MIN @ UTA  ...      199       172
# 123  2026-01-17T00:00:00    MIN @ SAS  ...      463       255
# 135  2026-01-16T00:00:00    MIN @ HOU  ...      310       341
# 144  2026-01-13T00:00:00    MIN @ MIL  ...      463       255
# 152  2026-01-11T00:00:00  MIN vs. SAS  ...      199       110
# 164  2026-01-10T00:00:00    MIN @ CLE  ...      310       172
# 177  2026-01-08T00:00:00  MIN vs. CLE  ...      463        80
# 188  2026-01-06T00:00:00  MIN vs. MIA  ...      199       234
# 203  2026-01-04T00:00:00    MIN @ WAS  ...      463       428
# 213  2026-01-03T00:00:00    MIN @ MIA  ...      463       255
# 222  2025-12-31T00:00:00    MIN @ ATL  ...      310       387
# 237  2025-12-29T00:00:00    MIN @ CHI  ...      463       234
# 248  2025-12-27T00:00:00  MIN vs. BKN  ...      463       255
# 262  2025-12-25T00:00:00    MIN @ DEN  ...      199       387
# 272  2025-12-23T00:00:00  MIN vs. NYK  ...       49       255
# 280  2025-12-21T00:00:00  MIN vs. MIL  ...      463       127
# 293  2025-12-19T00:00:00  MIN vs. OKC  ...      199       172
# 298  2025-12-17T00:00:00  MIN vs. MEM  ...      127       110
# 307  2025-12-14T00:00:00  MIN vs. SAC  ...      199       127
# 317  2025-12-12T00:00:00    MIN @ GSW  ...       80        87
# 330  2025-12-08T00:00:00  MIN vs. PHX  ...      463       522
# 339  2025-12-06T00:00:00  MIN vs. LAC  ...      199       428
# 351  2025-12-04T00:00:00    MIN @ NOP  ...      310       172
# 359  2025-12-02T00:00:00    MIN @ NOP  ...      463       172
# 368  2025-11-30T00:00:00  MIN vs. SAS  ...      463       127
# 381  2025-11-29T00:00:00  MIN vs. BOS  ...      310       172
# 393  2025-11-26T00:00:00    MIN @ OKC  ...      199       255
# 402  2025-11-24T00:00:00    MIN @ SAC  ...      199       144
# 413  2025-11-21T00:00:00    MIN @ PHX  ...      127       310
# 423  2025-11-19T00:00:00  MIN vs. WAS  ...      463       234
# 431  2025-11-17T00:00:00  MIN vs. DAL  ...      127       198
# 446  2025-11-15T00:00:00  MIN vs. DEN  ...      199       255
# 454  2025-11-14T00:00:00  MIN vs. SAC  ...      127        98
# 468  2025-11-10T00:00:00    MIN @ UTA  ...      127       198
# 478  2025-11-09T00:00:00    MIN @ SAC  ...      310       341
# 493  2025-11-07T00:00:00  MIN vs. UTA  ...      463       484
# 501  2025-11-05T00:00:00    MIN @ NYK  ...      127        87
# 513  2025-11-03T00:00:00    MIN @ BKN  ...       49        58
# 527  2025-11-01T00:00:00    MIN @ CHA  ...      310       127
# 540  2025-10-29T00:00:00  MIN vs. LAL  ...       80       198
# 549  2025-10-27T00:00:00  MIN vs. DEN  ...      127       234
# 561  2025-10-26T00:00:00  MIN vs. IND  ...       80       144
# 571  2025-10-24T00:00:00    MIN @ LAL  ...      199       214
# 588  2025-10-22T00:00:00    MIN @ POR  ...      463       367
# 613  2025-10-16T00:00:00    MIN @ CHI  ...      463       310
# 636  2025-10-09T00:00:00    MIN @ NYK  ...      463       484
# 659  2025-10-07T00:00:00  MIN vs. IND  ...      463       484
# 666  2025-10-04T00:00:00    MIN @ DEN  ...      463       341
#
#      PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 7                439                   469        48         3
# 18               522                   415        48         3
# 26               324                   223        48         3
# 36               439                   137        48         3
# 47               187                   318        48         3
# 57               112                   171        48         3
# 68               157                   215        48         3
# 76               112                    98        48         3
# 88               668                   228        48         3
# 105              324                   224        48         3
# 112              632                   117        48         3
# 123              187                   243        48         3
# 135              223                   241        48         3
# 144               34                   281        48         3
# 152              278                    26        48         3
# 164              600                   214        48         3
# 177               86                   192        48         3
# 188               58                   284        48         3
# 203               16                   298        48         3
# 213               25                   156        48         3
# 222              585                   314        48         3
# 237               16                   288        48         3
# 248              673                   195        48         3
# 262              112                   125        48         3
# 272              600                   203        48         3
# 280              348                   164        48         3
# 293              112                   326        48         3
# 298              556                    28         1         3
# 307               86                    23        48         3
# 317               77                   114        48         3
# 330              571                   427        48         3
# 339              490                   349        48         3
# 351              200                   256        48         3
# 359              200                   141        48         3
# 368              106                   208        48         3
# 381              140                   169        48         3
# 393              200                   313        48         3
# 402              200                   266        48         3
# 413              157                   260        48         3
# 423              140                   233        48         3
# 431                4                   233        48         3
# 446              676                   376        48         3
# 454               72                   136        48         3
# 468               58                   294        48         3
# 478               86                   237        48         3
# 493               44                   361        48         3
# 501              632                   185        48         3
# 513              112                    45        48         3
# 527              112                   199        48         3
# 540              187                   237        48         3
# 549              542                   290        48         3
# 561              200                   260        48         3
# 571              522                   271        48         3
# 588              455                   316        48         3
# 613              490                   454        48         3
# 636              140                   322        48         3
# 659              324                   512        48         3
# 666              112                   282        48         3
#
#      WNBA_FANTASY_PTS_RANK  AVAILABLE_FLAG  MIN_SEC  TEAM_COUNT
# 7                      467               1    23:53           1
# 18                     382               1    25:49           1
# 26                     164               1    31:00           1
# 36                     104               1    33:40           1
# 47                     290               1    17:38           1
# 57                     180               1    31:30           1
# 68                     238               1    27:34           1
# 76                      84               1    31:22           1
# 88                     104               1    32:23           1
# 105                    233               1    35:22           1
# 112                    120               1    33:01           1
# 123                    216               1    36:21           1
# 135                    238               1    39:53           1
# 144                    248               1    30:09           1
# 152                     30               1    38:03           1
# 164                    164               1    34:30           1
# 177                    120               1    34:03           1
# 188                    248               1    30:31           1
# 203                    333               1    22:35           1
# 213                    180               1    30:58           1
# 222                    333               1    25:39           1
# 237                    248               1    26:32           1
# 248                    199               1    31:38           1
# 262                    216               1    34:10           1
# 272                    216               1    32:12           1
# 280                    120               1    33:09           1
# 293                    265               1    33:23           1
# 298                     34               1    37:17           1
# 307                     44               1    33:40           1
# 317                    104               1    35:14           1
# 330                    423               1    27:22           1
# 339                    362               1    24:41           1
# 351                    216               1    32:05           1
# 359                    120               1    37:50           1
# 368                    164               1    29:26           1
# 381                    153               1    34:10           1
# 393                    290               1    31:18           1
# 402                    199               1    37:03           1
# 413                    265               1    31:36           1
# 423                    199               1    36:02           1
# 431                    216               1    26:18           1
# 446                    347               1    34:09           1
# 454                     95               1    30:26           1
# 468                    290               1    37:28           1
# 478                    282               1    28:21           1
# 493                    362               1    20:38           1
# 501                    120               1    36:02           1
# 513                     31               1    30:27           1
# 527                    153               1    31:19           1
# 540                    199               1    33:43           1
# 549                    265               1    29:53           1
# 561                    233               1    37:37           1
# 571                    265               1    28:16           1
# 588                    290               1    20:22           1
# 613                    405               1    18:23           1
# 636                    347               1    23:37           1
# 659                    467               1     8:56           1
# 666                    301               1    12:00           1
#
# [58 rows x 70 columns]

# %%
# Filter for Donte DiVincenzo and Jaden McDaniels
target_players = ['Donte DiVincenzo', 'Jaden McDaniels']
player_filtered = wolves_player_logs[wolves_player_logs['PLAYER_NAME'].isin(target_players)].copy()

# Group by game and sum their combined points
combined_pts = player_filtered.groupby('GAME_ID').agg({
    'PTS': 'sum',
    'GAME_DATE': 'first',
    'MATCHUP': 'first',
    'WL': 'first'  # Win/Loss column if available
}).reset_index()

combined_pts.columns = ['GAME_ID', 'COMBINED_PTS', 'GAME_DATE', 'MATCHUP', 'WL']

# Filter for games where combined PTS >= 30
games_30_plus = combined_pts[combined_pts['COMBINED_PTS'] >= 30].copy()

print(f"Games where Donte DiVincenzo and Jaden McDaniels combined for 30+ points: {len(games_30_plus)}")
print(f"\nGames breakdown:")
games_30_plus.sort_values('COMBINED_PTS', ascending=False).reset_index(drop=True)
# Out:
# Games where Donte DiVincenzo and Jaden McDaniels combined for 30+ points: 22
#
# Games breakdown:
#        GAME_ID  COMBINED_PTS            GAME_DATE      MATCHUP WL
# 0   0022500714            50  2026-02-02T00:00:00    MIN @ MEM  L
# 1   0022500530            48  2026-01-08T00:00:00  MIN vs. CLE  W
# 2   0022500156            47  2025-11-03T00:00:00    MIN @ BKN  W
# 3   0022500136            44  2025-10-29T00:00:00  MIN vs. LAL  L
# 4   0022501220            39  2025-12-14T00:00:00  MIN vs. SAC  W
# 5   0022501215            38  2025-12-12T00:00:00    MIN @ GSW  W
# 6   0022500008            37  2025-10-27T00:00:00  MIN vs. DEN  L
# 7   0022500598            34  2026-01-17T00:00:00    MIN @ SAS  L
# 8   0022500175            34  2025-11-05T00:00:00    MIN @ NYK  L
# 9   0022500727            34  2026-02-04T00:00:00    MIN @ TOR  W
# 10  0022500044            33  2025-11-14T00:00:00  MIN vs. SAC  W
# 11  0022500616            33  2026-01-20T00:00:00    MIN @ UTA  L
# 12  0022500321            32  2025-12-02T00:00:00    MIN @ NOP  W
# 13  0022500355            32  2025-12-06T00:00:00  MIN vs. LAC  W
# 14  0022500368            32  2025-12-17T00:00:00  MIN vs. MEM  L
# 15  0022500686            32  2026-01-29T00:00:00  MIN vs. OKC  W
# 16  0022500143            32  2025-11-01T00:00:00    MIN @ CHA  W
# 17  0022500306            31  2025-11-30T00:00:00  MIN vs. SAS  W
# 18  0022500552            31  2026-01-11T00:00:00  MIN vs. SAS  W
# 19  0022500700            31  2026-01-31T00:00:00    MIN @ MEM  W
# 20  0022500513            31  2026-01-06T00:00:00  MIN vs. MIA  W
# 21  0022500205            30  2025-11-10T00:00:00    MIN @ UTA  W

# %%
# Calculate win-loss record
# Check if WL column exists, if not parse from MATCHUP or other columns
if 'WL' in games_30_plus.columns and games_30_plus['WL'].notna().any():
    wins = (games_30_plus['WL'] == 'W').sum()
    losses = (games_30_plus['WL'] == 'L').sum()
else:
    # Try to parse from MATCHUP - if MIN is first, it's a home game
    # We'll need to check actual game results - let's check what columns are available
    print("WL column not found. Checking available columns...")
    print(games_30_plus.columns.tolist())
    # For now, we'll need to get win/loss from another source
    # Let's check if we can get it from the original dataframe
    game_results = wolves_player_logs.groupby('GAME_ID').agg({
        'WL': 'first'
    }).reset_index()
    
    games_30_plus = games_30_plus.merge(game_results, on='GAME_ID', how='left', suffixes=('', '_from_logs'))
    
    if 'WL_from_logs' in games_30_plus.columns:
        games_30_plus['WL'] = games_30_plus['WL_from_logs']
        wins = (games_30_plus['WL'] == 'W').sum()
        losses = (games_30_plus['WL'] == 'L').sum()
    else:
        wins = 0
        losses = 0
        print("Could not determine win/loss record from available data")

if wins + losses > 0:
    win_pct = wins / (wins + losses)
    print(f"\nTimberwolves Record when DiVincenzo + McDaniels combine for 30+ points:")
    print(f"Wins: {wins}")
    print(f"Losses: {losses}")
    print(f"Win Percentage: {win_pct:.3f} ({win_pct*100:.1f}%)")
    
    # Show the games
    print(f"\nGame Details:")
    display_cols = ['GAME_DATE', 'MATCHUP', 'COMBINED_PTS', 'WL']
    display_cols = [col for col in display_cols if col in games_30_plus.columns]
    print(games_30_plus[display_cols].sort_values('GAME_DATE', ascending=False))
else:
    print("No games found or unable to determine win/loss record")
# Out:
# Timberwolves Record when DiVincenzo + McDaniels combine for 30+ points:
# Wins: 15
# Losses: 7
# Win Percentage: 0.682 (68.2%)
#
# Game Details:
#               GAME_DATE      MATCHUP  COMBINED_PTS WL
# 53  2026-02-04T00:00:00    MIN @ TOR            34  W
# 52  2026-02-02T00:00:00    MIN @ MEM            50  L
# 51  2026-01-31T00:00:00    MIN @ MEM            31  W
# 50  2026-01-29T00:00:00  MIN vs. OKC            32  W
# 45  2026-01-20T00:00:00    MIN @ UTA            33  L
# 44  2026-01-17T00:00:00    MIN @ SAS            34  L
# 41  2026-01-11T00:00:00  MIN vs. SAS            31  W
# 39  2026-01-08T00:00:00  MIN vs. CLE            48  W
# 38  2026-01-06T00:00:00  MIN vs. MIA            31  W
# 29  2025-12-17T00:00:00  MIN vs. MEM            32  L
# 57  2025-12-14T00:00:00  MIN vs. SAC            39  W
# 56  2025-12-12T00:00:00    MIN @ GSW            38  W
# 27  2025-12-06T00:00:00  MIN vs. LAC            32  W
# 25  2025-12-02T00:00:00    MIN @ NOP            32  W
# 24  2025-11-30T00:00:00  MIN vs. SAS            31  W
# 8   2025-11-14T00:00:00  MIN vs. SAC            33  W
# 18  2025-11-10T00:00:00    MIN @ UTA            30  W
# 16  2025-11-05T00:00:00    MIN @ NYK            34  L
# 15  2025-11-03T00:00:00    MIN @ BKN            47  W
# 14  2025-11-01T00:00:00    MIN @ CHA            32  W
# 13  2025-10-29T00:00:00  MIN vs. LAL            44  L
# 4   2025-10-27T00:00:00  MIN vs. DEN            37  L

# %%
# Starting five: DiVincenzo, McDaniels, Anthony Edwards, Julius Randle, Rudy Gobert
starting_five = ['Donte DiVincenzo', 'Jaden McDaniels', 'Anthony Edwards', 'Julius Randle', 'Rudy Gobert']
# starting_five = ['Naz Reid', 'Bones Hyland']

# Filter for starting five players
starting_five_logs = wolves_player_logs[wolves_player_logs['PLAYER_NAME'].isin(starting_five)].copy()

# Create a pivot table: games as rows, players as columns, PTS as values
pivot_pts = starting_five_logs.pivot_table(
    index='GAME_ID',
    columns='PLAYER_NAME',
    values='PTS',
    aggfunc='first'
).reset_index()

# Get game metadata
game_metadata = starting_five_logs.groupby('GAME_ID').agg({
    'GAME_DATE': 'first',
    'MATCHUP': 'first',
    'WL': 'first'
}).reset_index()

# Merge with pivot table
starting_five_games = pivot_pts.merge(game_metadata, on='GAME_ID', how='left')

# Check if all five players scored at least 10 points in each game
# First, ensure all five player columns exist (fill missing with 0)
for player in starting_five:
    if player not in starting_five_games.columns:
        starting_five_games[player] = 0

# Filter for games where all five scored at least 10 points
all_10_plus = starting_five_games[
    # (starting_five_games['Naz Reid'] >= 10) &
    (starting_five_games['Jaden McDaniels'] >= 10) &
    (starting_five_games['Anthony Edwards'] >= 10) &
    (starting_five_games['Julius Randle'] >= 10) &
    (starting_five_games['Donte DiVincenzo'] >= 10) &
    (starting_five_games['Rudy Gobert'] >= 10)
].copy()

print(f"Games where all five starters scored 10+ points: {len(all_10_plus)}")
print(f"\nTotal games in dataset: {len(starting_five_games)}")
print(f"Percentage: {len(all_10_plus)/len(starting_five_games)*100:.1f}%")

# Display the games
if len(all_10_plus) > 0:
    display_cols = ['GAME_DATE', 'MATCHUP'] + starting_five + ['WL']
    display_cols = [col for col in display_cols if col in all_10_plus.columns]
    all_10_plus[display_cols].sort_values('GAME_DATE', ascending=False)
else:
    print("\nNo games found where all five starters scored 10+ points")
# Out:
# Games where all five starters scored 10+ points: 11
#
# Total games in dataset: 58
# Percentage: 19.0%

# %%
# Calculate win-loss record for games where all five starters scored 10+ points
from IPython.display import display

if len(all_10_plus) > 0:
    # Ensure WL column exists
    if 'WL' not in all_10_plus.columns or all_10_plus['WL'].isna().all():
        # Get WL from original dataframe if missing
        game_results = wolves_player_logs.groupby('GAME_ID').agg({
            'WL': 'first'
        }).reset_index()
        all_10_plus = all_10_plus.merge(game_results, on='GAME_ID', how='left', suffixes=('', '_from_logs'))
        if 'WL_from_logs' in all_10_plus.columns:
            all_10_plus['WL'] = all_10_plus['WL_from_logs']
    
    wins = (all_10_plus['WL'] == 'W').sum()
    losses = (all_10_plus['WL'] == 'L').sum()
    
    if wins + losses > 0:
        win_pct = wins / (wins + losses)
        print(f"\nTimberwolves Record when all five starters score 10+ points:")
        print(f"Wins: {wins}")
        print(f"Losses: {losses}")
        print(f"Win Percentage: {win_pct:.3f} ({win_pct*100:.1f}%)")
        
        # Show detailed breakdown
        print(f"\nGame Details:")
        display_cols = ['GAME_DATE', 'MATCHUP', 
                       'Naz Reid', 'Donte DiVincenzo', 'Jaden McDaniels', 
                       'Anthony Edwards', 'Julius Randle', 'Rudy Gobert', 'WL']
        display_cols = [col for col in display_cols if col in all_10_plus.columns]
        
        # Calculate total points for each game
        all_10_plus_display = all_10_plus[display_cols].copy()
        player_cols = [col for col in starting_five if col in all_10_plus_display.columns]
        if player_cols:
            all_10_plus_display['TOTAL_PTS'] = all_10_plus_display[player_cols].sum(axis=1)
            display_cols = ['GAME_DATE', 'MATCHUP'] + player_cols + ['TOTAL_PTS', 'WL']
            display_cols = [col for col in display_cols if col in all_10_plus_display.columns]
        
        # Display the dataframe (using print like in Cell 4)
        result_df = all_10_plus_display[display_cols].sort_values('GAME_DATE', ascending=False)
        print(result_df)
    else:
        print("Could not determine win/loss record")
else:
    print("No games found where all five starters scored 10+ points")
# Out:
# Timberwolves Record when all five starters score 10+ points:
# Wins: 9
# Losses: 2
# Win Percentage: 0.818 (81.8%)
#
# Game Details:
#               GAME_DATE      MATCHUP  Donte DiVincenzo  Jaden McDaniels  \
# 53  2026-02-04T00:00:00    MIN @ TOR              15.0             19.0
# 50  2026-01-29T00:00:00  MIN vs. OKC              11.0             21.0
# 46  2026-01-22T00:00:00  MIN vs. CHI              11.0             16.0
# 45  2026-01-20T00:00:00    MIN @ UTA              15.0             18.0
# 39  2026-01-08T00:00:00  MIN vs. CLE              22.0             26.0
# 38  2026-01-06T00:00:00  MIN vs. MIA              12.0             19.0
# 26  2025-12-04T00:00:00    MIN @ NOP              15.0             14.0
# 25  2025-12-02T00:00:00    MIN @ NOP              15.0             17.0
# 20  2025-11-17T00:00:00  MIN vs. DAL              14.0             15.0
# 8   2025-11-14T00:00:00  MIN vs. SAC              20.0             13.0
# 18  2025-11-10T00:00:00    MIN @ UTA              14.0             16.0
#
#     Anthony Edwards  Julius Randle  Rudy Gobert  TOTAL_PTS WL
# 53             30.0           17.0         10.0       91.0  W
# 50             26.0           13.0         14.0       85.0  W
# 46             20.0           30.0         10.0       87.0  L
# 45             38.0           19.0         11.0      101.0  L
# 39             25.0           28.0         11.0      112.0  W
# 38             26.0           15.0         13.0       85.0  W
# 26             11.0           28.0         15.0       83.0  W
# 25             44.0           16.0         26.0      118.0  W
# 20             13.0           12.0         15.0       69.0  W
# 8              30.0           26.0         11.0      100.0  W
# 18             35.0           27.0         14.0      106.0  W

# %%
# Filter for Julius Randle games
randle_logs = wolves_player_logs[wolves_player_logs['PLAYER_NAME'] == 'Julius Randle'].copy()

# Check what column name is used for three-pointers made
# Common names: FG3M, FG3_M, FG3MADE, or similar
three_pt_col = None
for col in ['FG3M', 'FG3_M', 'FG3MADE', 'FG3A_MADE']:
    if col in randle_logs.columns:
        three_pt_col = col
        break

if three_pt_col is None:
    # List available columns to help identify the correct one
    print("Three-pointer column not found. Available columns:")
    print([col for col in randle_logs.columns if '3' in col.upper() or 'THREE' in col.upper()])
    # Try common alternative
    three_pt_col = 'FG3M' if 'FG3M' in randle_logs.columns else None

if three_pt_col:
    # Filter for games where Randle made at least 3 three-pointers
    randle_3plus_3pt = randle_logs[randle_logs[three_pt_col] >= 3].copy()
    
    print(f"Games where Julius Randle made 3+ three-pointers: {len(randle_3plus_3pt)}")
    print(f"\nTotal games played by Randle: {len(randle_logs)}")
    print(f"Percentage: {len(randle_3plus_3pt)/len(randle_logs)*100:.1f}%")
    
    # Calculate win-loss record
    if 'WL' not in randle_3plus_3pt.columns or randle_3plus_3pt['WL'].isna().all():
        # Get WL from original dataframe if missing
        game_results = wolves_player_logs.groupby('GAME_ID').agg({
            'WL': 'first'
        }).reset_index()
        randle_3plus_3pt = randle_3plus_3pt.merge(game_results, on='GAME_ID', how='left', suffixes=('', '_from_logs'))
        if 'WL_from_logs' in randle_3plus_3pt.columns:
            randle_3plus_3pt['WL'] = randle_3plus_3pt['WL_from_logs']
    
    wins = (randle_3plus_3pt['WL'] == 'W').sum()
    losses = (randle_3plus_3pt['WL'] == 'L').sum()
    
    if wins + losses > 0:
        win_pct = wins / (wins + losses)
        print(f"\nTimberwolves Record when Julius Randle makes 3+ three-pointers:")
        print(f"Wins: {wins}")
        print(f"Losses: {losses}")
        print(f"Win Percentage: {win_pct:.3f} ({win_pct*100:.1f}%)")
        
        # Show the games
        print(f"\nGame Details:")
        display_cols = ['GAME_DATE', 'MATCHUP', 'PTS', three_pt_col, 'WL']
        display_cols = [col for col in display_cols if col in randle_3plus_3pt.columns]
        print(randle_3plus_3pt[display_cols].sort_values('GAME_DATE', ascending=False))
    else:
        print("Could not determine win/loss record")
else:
    print("Could not find three-pointer column in the data")
# Out:
# Games where Julius Randle made 3+ three-pointers: 11
#
# Total games played by Randle: 57
# Percentage: 19.3%
#
# Timberwolves Record when Julius Randle makes 3+ three-pointers:
# Wins: 6
# Losses: 5
# Win Percentage: 0.545 (54.5%)
#
# Game Details:
#                GAME_DATE      MATCHUP  PTS  FG3M WL
# 42   2026-01-31T00:00:00    MIN @ MEM   27     4  W
# 100  2026-01-22T00:00:00  MIN vs. CHI   30     3  L
# 140  2026-01-13T00:00:00    MIN @ MIL   29     4  W
# 174  2026-01-08T00:00:00  MIN vs. CLE   28     3  W
# 220  2025-12-31T00:00:00    MIN @ ATL   19     3  L
# 380  2025-11-29T00:00:00  MIN vs. BOS   16     3  W
# 500  2025-11-05T00:00:00    MIN @ NYK   32     3  L
# 525  2025-11-01T00:00:00    MIN @ CHA   30     3  W
# 537  2025-10-29T00:00:00  MIN vs. LAL   33     4  L
# 570  2025-10-24T00:00:00    MIN @ LAL   26     4  L
# 585  2025-10-22T00:00:00    MIN @ POR   19     3  W

# %%
# Filter for Julius Randle games
randle_logs = wolves_player_logs[wolves_player_logs['PLAYER_NAME'] == 'Julius Randle'].copy()

# Check what column name is used for three-pointers made
# Common names: FG3M, FG3_M, FG3MADE, or similar
three_pt_col = None
for col in ['FG3M', 'FG3_M', 'FG3MADE', 'FG3A_MADE']:
    if col in randle_logs.columns:
        three_pt_col = col
        break

if three_pt_col is None:
    # List available columns to help identify the correct one
    print("Three-pointer column not found. Available columns:")
    print([col for col in randle_logs.columns if '3' in col.upper() or 'THREE' in col.upper()])
    # Try common alternative
    three_pt_col = 'FG3M' if 'FG3M' in randle_logs.columns else None

if three_pt_col:
    # Filter for games where Randle made at least 3 three-pointers
    randle_3plus_3pt = randle_logs[randle_logs[three_pt_col] >= 3].copy()
    
    print(f"Games where Julius Randle made 3+ three-pointers: {len(randle_3plus_3pt)}")
    print(f"\nTotal games played by Randle: {len(randle_logs)}")
    print(f"Percentage: {len(randle_3plus_3pt)/len(randle_logs)*100:.1f}%")
    
    # Calculate win-loss record
    if 'WL' not in randle_3plus_3pt.columns or randle_3plus_3pt['WL'].isna().all():
        # Get WL from original dataframe if missing
        game_results = wolves_player_logs.groupby('GAME_ID').agg({
            'WL': 'first'
        }).reset_index()
        randle_3plus_3pt = randle_3plus_3pt.merge(game_results, on='GAME_ID', how='left', suffixes=('', '_from_logs'))
        if 'WL_from_logs' in randle_3plus_3pt.columns:
            randle_3plus_3pt['WL'] = randle_3plus_3pt['WL_from_logs']
    
    wins = (randle_3plus_3pt['WL'] == 'W').sum()
    losses = (randle_3plus_3pt['WL'] == 'L').sum()
    
    if wins + losses > 0:
        win_pct = wins / (wins + losses)
        print(f"\nTimberwolves Record when Julius Randle makes 3+ three-pointers:")
        print(f"Wins: {wins}")
        print(f"Losses: {losses}")
        print(f"Win Percentage: {win_pct:.3f} ({win_pct*100:.1f}%)")
        
        # Show the games
        print(f"\nGame Details:")
        display_cols = ['GAME_DATE', 'MATCHUP', 'PTS', three_pt_col, 'WL']
        display_cols = [col for col in display_cols if col in randle_3plus_3pt.columns]
        print(randle_3plus_3pt[display_cols].sort_values('GAME_DATE', ascending=False))
    else:
        print("Could not determine win/loss record")
else:
    print("Could not find three-pointer column in the data")
# Out:
# Games where Julius Randle made 3+ three-pointers: 11
#
# Total games played by Randle: 57
# Percentage: 19.3%
#
# Timberwolves Record when Julius Randle makes 3+ three-pointers:
# Wins: 6
# Losses: 5
# Win Percentage: 0.545 (54.5%)
#
# Game Details:
#                GAME_DATE      MATCHUP  PTS  FG3M WL
# 42   2026-01-31T00:00:00    MIN @ MEM   27     4  W
# 100  2026-01-22T00:00:00  MIN vs. CHI   30     3  L
# 140  2026-01-13T00:00:00    MIN @ MIL   29     4  W
# 174  2026-01-08T00:00:00  MIN vs. CLE   28     3  W
# 220  2025-12-31T00:00:00    MIN @ ATL   19     3  L
# 380  2025-11-29T00:00:00  MIN vs. BOS   16     3  W
# 500  2025-11-05T00:00:00    MIN @ NYK   32     3  L
# 525  2025-11-01T00:00:00    MIN @ CHA   30     3  W
# 537  2025-10-29T00:00:00  MIN vs. LAL   33     4  L
# 570  2025-10-24T00:00:00    MIN @ LAL   26     4  L
# 585  2025-10-22T00:00:00    MIN @ POR   19     3  W

# %%
# Find games where at least 4 players scored 20+ points
# Group by game and count how many players scored 20+ points in each game
games_with_20_plus = wolves_player_logs[wolves_player_logs['PTS'] >= 20].copy()

# Count how many players scored 20+ in each game
players_20_plus_per_game = games_with_20_plus.groupby('GAME_ID').agg({
    'PLAYER_NAME': 'count',
    'GAME_DATE': 'first',
    'MATCHUP': 'first',
    'WL': 'first'
}).reset_index()

players_20_plus_per_game.columns = ['GAME_ID', 'PLAYERS_20_PLUS', 'GAME_DATE', 'MATCHUP', 'WL']

# Filter for games where at least 4 players scored 20+ points
games_4plus_20pts = players_20_plus_per_game[players_20_plus_per_game['PLAYERS_20_PLUS'] >= 4].copy()

print(f"Games where at least 4 players scored 20+ points: {len(games_4plus_20pts)}")
print(f"\nTotal games in dataset: {len(players_20_plus_per_game)}")
if len(players_20_plus_per_game) > 0:
    print(f"Percentage: {len(games_4plus_20pts)/len(players_20_plus_per_game)*100:.1f}%")

# Display the games
if len(games_4plus_20pts) > 0:
    display(games_4plus_20pts.sort_values('GAME_DATE', ascending=False))
else:
    print("\nNo games found where at least 4 players scored 20+ points")
# Out:
# Games where at least 4 players scored 20+ points: 2
#
# Total games in dataset: 57
# Percentage: 3.5%
#        GAME_ID  PLAYERS_20_PLUS            GAME_DATE      MATCHUP WL
# 50  0022500700                4  2026-01-31T00:00:00    MIN @ MEM  W
# 39  0022500530                4  2026-01-08T00:00:00  MIN vs. CLE  W

# %%
# Calculate win-loss record for games where at least 4 players scored 20+ points
from IPython.display import display

if len(games_4plus_20pts) > 0:
    # Ensure WL column exists
    if 'WL' not in games_4plus_20pts.columns or games_4plus_20pts['WL'].isna().all():
        # Get WL from original dataframe if missing
        game_results = wolves_player_logs.groupby('GAME_ID').agg({
            'WL': 'first'
        }).reset_index()
        games_4plus_20pts = games_4plus_20pts.merge(game_results, on='GAME_ID', how='left', suffixes=('', '_from_logs'))
        if 'WL_from_logs' in games_4plus_20pts.columns:
            games_4plus_20pts['WL'] = games_4plus_20pts['WL_from_logs']
    
    wins = (games_4plus_20pts['WL'] == 'W').sum()
    losses = (games_4plus_20pts['WL'] == 'L').sum()
    
    if wins + losses > 0:
        win_pct = wins / (wins + losses)
        print(f"\nTimberwolves Record when at least 4 players score 20+ points:")
        print(f"Wins: {wins}")
        print(f"Losses: {losses}")
        print(f"Win Percentage: {win_pct:.3f} ({win_pct*100:.1f}%)")
        
        # Show detailed breakdown
        print(f"\nGame Details:")
        display_cols = ['GAME_DATE', 'MATCHUP', 'PLAYERS_20_PLUS', 'WL']
        display_cols = [col for col in display_cols if col in games_4plus_20pts.columns]
        
        # Get player names who scored 20+ for each game
        games_4plus_20pts_display = games_4plus_20pts[display_cols].copy()
        
        # For each game, get the list of players who scored 20+
        player_lists = []
        for game_id in games_4plus_20pts_display['GAME_ID']:
            game_players = games_with_20_plus[games_with_20_plus['GAME_ID'] == game_id]['PLAYER_NAME'].tolist()
            player_lists.append(', '.join(game_players))
        
        games_4plus_20pts_display['PLAYERS'] = player_lists
        
        # Display the dataframe
        result_df = games_4plus_20pts_display.sort_values('GAME_DATE', ascending=False)
        print(result_df)
    else:
        print("Could not determine win/loss record")
else:
    print("No games found where at least 4 players scored 20+ points")
# Out:
# Timberwolves Record when at least 4 players score 20+ points:
# Wins: 2
# Losses: 0
# Win Percentage: 1.000 (100.0%)
#
# Game Details:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GAME_ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 35
#      33 # For each game, get the list of players who scored 20+
#      34 player_lists = []
# ---> 35 for game_id in games_4plus_20pts_display['GAME_ID']:
#      36     game_players = games_with_20_plus[games_with_20_plus['GAME_ID'] == game_id]['PLAYER_NAME'].tolist()
#      37     player_lists.append(', '.join(game_players))
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Desktop/PycharmProjects/NBA/venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'GAME_ID'
